# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image
from utils import *

classifier = ClassifierGenerator(model_name="Modelo_Kyoto-1")
classifier.load_model('Modelos/Modelo_Kyoto-1/Classificador-Kyoto/Estrutura/Classificador_Modelo_Kyoto-1.keras', None)
classifier.encoder.summary()
# Out:
# 2025-06-04 17:13:37.976557: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-04 17:13:37.990838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-04 17:13:37.995646: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 17:13:38.006504: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
data, df = preprocessing_dataframe('CSV/PUC/PUC_test.csv', False, False)
# Out:
# Found 333945 validated image filenames belonging to 2 classes.
# Imagens totais: 333945

# %%
errors_heatmap(df, classifier)
# Out:
# Tamanho dos heatmaps: 4
# Tamanho dos heatmaps: 4
# Tamanho dos heatmaps: 4
# Tamanho dos heatmaps: 4
# /home/lucas/PIBIC/utils/view/heatmap.py:275: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
